# %%
# naložimo paket
import pandas as pd

# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 10 vrstic
pd.set_option("display.max_rows", 10)

# izberemo interaktivni "notebook" stil risanja
# %matplotlib inline

# naložimo razpredelnico, s katero bomo delali
igralci = pd.read_csv("igralci_url.csv")

# %%
igralci
# Out:
#           ime    priimek  starost pozicija  stevilo_iger  povprecje_tocke  \
# 0    Precious    Achiuwa       23        C            55              9.2
# 1      Steven      Adams       29        C            42              8.6
# 2         Bam    Adebayo       25        C            75             20.4
# 3       Ochai     Agbaji       22       SG            59              7.9
# 4       Santi     Aldama       22       PF            77              9.0
# ..        ...        ...      ...      ...           ...              ...
# 534  Thaddeus      Young       34       PF            54              4.4
# 535      Trae      Young       24       PG            73             26.2
# 536      Omer  Yurtseven       24        C             9              4.4
# 537      Cody     Zeller       30        C            15              6.5
# 538     Ivica      Zubac       25        C            76             10.8
#
#      povprecje_osebne_napake  povprecje_asistence  povprecje_skoki  \
# 0                        1.9                  0.9              6.0
# 1                        2.3                  2.3             11.5
# 2                        2.8                  3.2              9.2
# 3                        1.7                  1.1              2.1
# 4                        1.9                  1.3              4.8
# ..                       ...                  ...              ...
# 534                      1.6                  1.4              3.1
# 535                      1.4                 10.2              3.0
# 536                      1.8                  0.2              2.6
# 537                      2.2                  0.7              4.3
# 538                      2.9                  1.0              9.9
#
#      povprecje_trojke
# 0                 0.5
# 1                 0.0
# 2                 0.0
# 3                 1.4
# 4                 1.2
# ..                ...
# 534               0.1
# 535               2.1
# 536               0.3
# 537               0.0
# 538               0.0
#
# [539 rows x 10 columns]

# %%
igralci.tail(10)
# Out:
#            ime    priimek  starost pozicija  stevilo_iger  povprecje_tocke  \
# 529      James    Wiseman       21        C            45             10.0
# 530  Christian       Wood       27        C            67             16.6
# 531      Delon     Wright       30       PG            50              7.4
# 532   McKinley     Wright       24       PG            27              4.2
# 533       Gabe       York       29       SG             3              8.0
# 534   Thaddeus      Young       34       PF            54              4.4
# 535       Trae      Young       24       PG            73             26.2
# 536       Omer  Yurtseven       24        C             9              4.4
# 537       Cody     Zeller       30        C            15              6.5
# 538      Ivica      Zubac       25        C            76             10.8
#
#      povprecje_osebne_napake  povprecje_asistence  povprecje_skoki  \
# 529                      2.4                  0.7              5.9
# 530                      2.5                  1.8              7.3
# 531                      1.2                  3.9              3.6
# 532                      0.9                  2.1              1.7
# 533                      1.7                  1.7              2.0
# 534                      1.6                  1.4              3.1
# 535                      1.4                 10.2              3.0
# 536                      1.8                  0.2              2.6
# 537                      2.2                  0.7              4.3
# 538                      2.9                  1.0              9.9
#
#      povprecje_trojke
# 529               0.1
# 530               1.6
# 531               0.8
# 532               0.3
# 533               2.0
# 534               0.1
# 535               2.1
# 536               0.3
# 537               0.0
# 538               0.0

# %%
igralci.describe()
# Out:
#           starost  stevilo_iger  povprecje_tocke  povprecje_osebne_napake  \
# count  539.000000    539.000000       539.000000               539.000000
# mean    25.727273     48.040816         9.121336                 1.688126
# std      4.290326     24.650686         6.842216                 0.792206
# min     19.000000      1.000000         0.000000                 0.000000
# 25%     23.000000     30.500000         4.150000                 1.200000
# 50%     25.000000     54.000000         7.000000                 1.600000
# 75%     28.500000     68.000000        12.100000                 2.200000
# max     42.000000     83.000000        33.100000                 5.000000
#
#        povprecje_asistence  povprecje_skoki  povprecje_trojke
# count           539.000000       539.000000        539.000000
# mean              2.068831         3.543043          0.990538
# std               1.933079         2.347046          0.872442
# min               0.000000         0.000000          0.000000
# 25%               0.800000         1.800000          0.300000
# 50%               1.400000         3.000000          0.800000
# 75%               2.750000         4.500000          1.500000
# max              10.700000        12.500000          4.900000

# %%
igralci.sort_values(by="povprecje_tocke", ascending = False, inplace = True)
igralci
print(igralci.head(5))
igralci["povprecje_tocke"]
# Out:
#          ime             priimek  starost pozicija  stevilo_iger  \
# 142     Joel              Embiid       28        C            66
# 124     Luka              Dončić       23       PG            66
# 291   Damian             Lillard       32       PG            58
# 163     Shai  Gilgeous-Alexander       24       PG            68
# 10   Giannis       Antetokounmpo       28       PF            63
#
#      povprecje_tocke  povprecje_osebne_napake  povprecje_asistence  \
# 142             33.1                      3.1                  4.2
# 124             32.4                      2.5                  8.0
# 291             32.2                      1.9                  7.3
# 163             31.4                      2.8                  5.5
# 10              31.1                      3.1                  5.7
#
#      povprecje_skoki  povprecje_trojke  leta
# 142             10.2               1.0    20
# 124              8.6               2.8    20
# 291              4.8               4.2    30
# 163              4.8               0.9    20
# 10              11.8               0.7    20
# 142    33.1
# 124    32.4
# 291    32.2
# 163    31.4
# 10     31.1
#        ...
# 72      0.0
# 514     0.0
# 150     0.0
# 232     0.0
# 66      0.0
# Name: povprecje_tocke, Length: 539, dtype: float64

# %%
igralci["povprecje_tocke"]
# Out:
# 142    33.1
# 124    32.4
# 291    32.2
# 163    31.4
# 10     31.1
#        ...
# 72      0.0
# 514     0.0
# 150     0.0
# 232     0.0
# 66      0.0
# Name: povprecje_tocke, Length: 539, dtype: float64

# %%
print(type(igralci['povprecje_tocke']))
print(type(igralci[['povprecje_tocke']]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
zaokrozeno_povprecje_tocke = igralci['povprecje_tocke'].round()
zaokrozeno_povprecje_tocke
# Out:
# 142    33.0
# 124    32.0
# 291    32.0
# 163    31.0
# 10     31.0
#        ...
# 72      0.0
# 514     0.0
# 150     0.0
# 232     0.0
# 66      0.0
# Name: povprecje_tocke, Length: 539, dtype: float64

# %%
igralci['zaokrozeno_povprecje_tocke'] = zaokrozeno_povprecje_tocke
igralci
# Out:
#           ime             priimek  starost pozicija  stevilo_iger  \
# 142      Joel              Embiid       28        C            66
# 124      Luka              Dončić       23       PG            66
# 291    Damian             Lillard       32       PG            58
# 163      Shai  Gilgeous-Alexander       24       PG            68
# 10    Giannis       Antetokounmpo       28       PF            63
# ..        ...                 ...      ...      ...           ...
# 72     Deonte              Burton       29       PF             2
# 514   Alondes            Williams       23       SG             1
# 150   Michael              Foster       20       PF             1
# 232     Frank             Jackson       24       PG             1
# 66   Sterling               Brown       27       SF             4
#
#      povprecje_tocke  povprecje_osebne_napake  povprecje_asistence  \
# 142             33.1                      3.1                  4.2
# 124             32.4                      2.5                  8.0
# 291             32.2                      1.9                  7.3
# 163             31.4                      2.8                  5.5
# 10              31.1                      3.1                  5.7
# ..               ...                      ...                  ...
# 72               0.0                      0.0                  0.0
# 514              0.0                      1.0                  0.0
# 150              0.0                      0.0                  0.0
# 232              0.0                      0.0                  1.0
# 66               0.0                      1.0                  0.5
#
#      povprecje_skoki  povprecje_trojke  zaokrozeno_povprecje_tocke
# 142             10.2               1.0                        33.0
# 124              8.6               2.8                        32.0
# 291              4.8               4.2                        32.0
# 163              4.8               0.9                        31.0
# 10              11.8               0.7                        31.0
# ..               ...               ...                         ...
# 72               0.0               0.0                         0.0
# 514              1.0               0.0                         0.0
# 150              0.0               0.0                         0.0
# 232              2.0               0.0                         0.0
# 66               2.0               0.0                         0.0
#
# [539 rows x 11 columns]

# %%
igralci.drop("zaokrozeno_povprecje_tocke", axis = 1, inplace = True)
igralci
# Out:
#           ime             priimek  starost pozicija  stevilo_iger  \
# 142      Joel              Embiid       28        C            66
# 124      Luka              Dončić       23       PG            66
# 291    Damian             Lillard       32       PG            58
# 163      Shai  Gilgeous-Alexander       24       PG            68
# 10    Giannis       Antetokounmpo       28       PF            63
# ..        ...                 ...      ...      ...           ...
# 72     Deonte              Burton       29       PF             2
# 514   Alondes            Williams       23       SG             1
# 150   Michael              Foster       20       PF             1
# 232     Frank             Jackson       24       PG             1
# 66   Sterling               Brown       27       SF             4
#
#      povprecje_tocke  povprecje_osebne_napake  povprecje_asistence  \
# 142             33.1                      3.1                  4.2
# 124             32.4                      2.5                  8.0
# 291             32.2                      1.9                  7.3
# 163             31.4                      2.8                  5.5
# 10              31.1                      3.1                  5.7
# ..               ...                      ...                  ...
# 72               0.0                      0.0                  0.0
# 514              0.0                      1.0                  0.0
# 150              0.0                      0.0                  0.0
# 232              0.0                      0.0                  1.0
# 66               0.0                      1.0                  0.5
#
#      povprecje_skoki  povprecje_trojke
# 142             10.2               1.0
# 124              8.6               2.8
# 291              4.8               4.2
# 163              4.8               0.9
# 10              11.8               0.7
# ..               ...               ...
# 72               0.0               0.0
# 514              1.0               0.0
# 150              0.0               0.0
# 232              2.0               0.0
# 66               2.0               0.0
#
# [539 rows x 10 columns]

# %%
podtabela = igralci[["ime", "priimek", "starost", "povprecje_tocke"]].copy()

# %%
podtabela["zaokrozeno_povprecje_tocke"] = igralci["povprecje_tocke"].round()

# %%
podtabela
# Out:
#           ime             priimek  starost  povprecje_tocke  \
# 142      Joel              Embiid       28             33.1
# 124      Luka              Dončić       23             32.4
# 291    Damian             Lillard       32             32.2
# 163      Shai  Gilgeous-Alexander       24             31.4
# 10    Giannis       Antetokounmpo       28             31.1
# ..        ...                 ...      ...              ...
# 72     Deonte              Burton       29              0.0
# 514   Alondes            Williams       23              0.0
# 150   Michael              Foster       20              0.0
# 232     Frank             Jackson       24              0.0
# 66   Sterling               Brown       27              0.0
#
#      zaokrozeno_povprecje_tocke
# 142                        33.0
# 124                        32.0
# 291                        32.0
# 163                        31.0
# 10                         31.0
# ..                          ...
# 72                          0.0
# 514                         0.0
# 150                         0.0
# 232                         0.0
# 66                          0.0
#
# [539 rows x 5 columns]

# %%
filter = igralci['starost'] > 39

# %%
igralci[filter]
# Out:
#         ime priimek  starost pozicija  stevilo_iger  povprecje_tocke  \
# 200  Udonis  Haslem       42        C             7              3.9
#
#      povprecje_osebne_napake  povprecje_asistence  povprecje_skoki  \
# 200                      1.6                  0.0              1.6
#
#      povprecje_trojke  leta
# 200               0.4    40

# %%
igralci_po_tockah = podtabela.groupby(by = "zaokrozeno_povprecje_tocke")[["ime"]].count()
igralci_po_tockah
# Out:
#                             ime
# zaokrozeno_povprecje_tocke
# 0.0                           8
# 1.0                          20
# 2.0                          38
# 3.0                          36
# 4.0                          50
# ...                         ...
# 29.0                          3
# 30.0                          1
# 31.0                          2
# 32.0                          2
# 33.0                          1
#
# [34 rows x 1 columns]

# %%
igralci_po_tockah.plot.bar()
# Out:
# <Axes: xlabel='zaokrozeno_povprecje_tocke'>

# %%
podtabela.hist()
# Out:
# array([[<Axes: title={'center': 'starost'}>,
#         <Axes: title={'center': 'povprecje_tocke'}>],
#        [<Axes: title={'center': 'zaokrozeno_povprecje_tocke'}>, <Axes: >]],
#       dtype=object)

# %%
tocke_po_letih = igralci[["povprecje_tocke", "starost"]].groupby(by="starost").mean()
tocke_po_letih.plot(ylabel = "povprecje tock")
# Out:
# <Axes: xlabel='starost', ylabel='povprecje tock'>

# %%
igralci["leta"] = (igralci[["starost"]] // 10) * 10

# %%
igralci["leta"] == 20
# Out:
# 142     True
# 124     True
# 291    False
# 163     True
# 10      True
#        ...
# 72      True
# 514     True
# 150     True
# 232     True
# 66      True
# Name: leta, Length: 539, dtype: bool

# %%
def razvrsti_po_desetletjih(igralci):
    deset = 0
    dvajset = 0
    trideset = 0 
    stirideset = 0
    for i in range(len(igralci)):
        if igralci["leta"][i] == 10:
            deset += 1  
        elif igralci["leta"][i] == 20:
            dvajset += 1  
        elif igralci["leta"][i] == 30:
            trideset += 1
        elif igralci["leta"][i] == 40:
            stirideset += 1
    return deset, dvajset, trideset, stirideset

# %%
igralci_desetletje = razvrsti_po_desetletjih(igralci)
razvrsti_po_desetletjih(igralci)
# Out:
# (14, 416, 108, 1)

# %%
igralci.groupby(["leta"])["povprecje_tocke"].mean().plot.bar()
# Out:
# <Axes: xlabel='leta'>

# %%
podtabela2 = igralci["pozicija"] == "C"

# %%
podtabela2
# Out:
# 142     True
# 124    False
# 291    False
# 163    False
# 10     False
#        ...
# 72     False
# 514    False
# 150    False
# 232    False
# 66     False
# Name: pozicija, Length: 539, dtype: bool
